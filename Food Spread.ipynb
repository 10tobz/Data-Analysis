# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Food Balance Sheet.csv')

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#Total Animal Fat Produced in 2014:
df_fat= df.groupby('Item')
df_fat.first()
# Out:
#                      Area Code     Area  Item Code  Element Code  \
# Item
# Alcohol, Non-Food            4  Algeria       2659          5511
# Alcoholic Beverages          4  Algeria       2924          5511
# Animal Products              4  Algeria       2941           664
# Animal fats                  4  Algeria       2946          5511
# Apples and products          4  Algeria       2617          5511
# ...                        ...      ...        ...           ...
# Vegetables, Other            4  Algeria       2605          5511
# Vegetal Products             4  Algeria       2903           664
# Wheat and products           4  Algeria       2511          5511
# Wine                         4  Algeria       2655          5511
# Yams                         4  Algeria       2535          5911
#
#                                            Element             Unit   Y2014  \
# Item
# Alcohol, Non-Food                       Production      1000 tonnes     0.0
# ...

# %%
total_fat = df_fat.get_group('Animal fats')
total_fat['Y2014'].sum()
# Out:
# 209460.54

# %%
total_fat['Y2017'].sum()
# Out:
# 269617.53

# %%
df['Y2015'].mean()
# Out:
# 135.23596649549236

# %%
df['Y2015'].std()
# Out:
# 1603.4039839423301

# %%
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
total = df['Y2016'].count()
null = df['Y2016'].isnull().sum()
perc = (null/total)*100
print('sum of missing values in 2016 is', null)
print('percentage of missing values in 2016 is', perc)
total
# Out:
# sum of missing values in 2016 is 1535
# percentage of missing values in 2016 is 2.583827093994075
# 59408

# %%
df.corr()
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015  \
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208
#
#                  Y2016     Y2017     Y2018
# Area Code     0.005247  0.005006  0.005665
# Item Code     0.020109  0.021494  0.021314
# Element Code  0.023444  0.024254  0.024279
# Y2014         0.996081  0.995230  0.994872
# Y2015         0.995739  0.988048  0.988208
# Y2016         1.000000  0.992785  0.992757
# ...

# %%
df_gr = df.groupby('Element')
df_gr.first()
# Out:
#                                         Area Code     Area  Item Code  \
# Element
# Domestic supply quantity                        4  Algeria       2501
# Export Quantity                                 4  Algeria       2905
# Fat supply quantity (g/capita/day)              4  Algeria       2901
# Feed                                            4  Algeria       2905
# Food                                            4  Algeria       2905
# Food supply (kcal/capita/day)                   4  Algeria       2901
# Food supply quantity (kg/capita/yr)             4  Algeria       2905
# Import Quantity                                 4  Algeria       2905
# Losses                                          4  Algeria       2905
# Other uses (non-food)                           4  Algeria       2905
# Processing                                      4  Algeria       2905
# Production                                      4  Algeria       2905
# ...

# %%
print(df_gr.get_group('Import Quantity')['Y2014'].sum())
print(df_gr.get_group('Import Quantity')['Y2015'].sum())
print(df_gr.get_group('Import Quantity')['Y2016'].sum())
print(df_gr.get_group('Import Quantity')['Y2017'].sum())
print(df_gr.get_group('Import Quantity')['Y2018'].sum())
# Out:
# 274144.48
# 267018.45999999996
# 286582.78
# 294559.09
# 287997.08999999997

# %%
df_gr.get_group('Production')['Y2014'].sum()
# Out:
# 1931287.75

# %%
select_df = df[['Y2018', 'Element']]
print(select_df.groupby('Element').get_group('Seed').sum())
print(select_df.groupby('Element').get_group('Protein supply quantity (g/capita/day)').sum())
print(select_df.groupby('Element').get_group('Food supply quantity (kg/capita/yr)').sum())
print(select_df.groupby('Element').get_group('Food supply (kcal/capita/day)').sum())
# Out:
# Y2018                                               25263.14
# Element    SeedSeedSeedSeedSeedSeedSeedSeedSeedSeedSeedSe...
# dtype: object
# Y2018                                               11833.56
# Element    Protein supply quantity (g/capita/day)Protein ...
# dtype: object
# Y2018                                               49056.85
# Element    Food supply quantity (kg/capita/yr)Food supply...
# dtype: object
# Y2018                                               455261.0
# Element    Food supply (kcal/capita/day)Food supply (kcal...
# dtype: object

# %%
df[df['Area'] == 'Algeria'].groupby('Element').get_group('Import Quantity')['Y2018'].sum()
# Out:
# 36238.29

# %%
df['Area'].nunique()
# Out:
# 49

# %%
sel = df.select_dtypes(include='object').columns.tolist()
for i in sel:
    obs = df[i].value_counts()
